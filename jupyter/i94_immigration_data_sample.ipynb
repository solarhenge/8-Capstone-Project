# %%
# Do all imports and installs here
from pyspark.sql.functions import udf
from pyspark.sql.session import SparkSession
import datetime
import pandas as pd
import pyspark.sql.functions as F
import psycopg2
from pyspark.sql.types import IntegerType

# %%
spark = SparkSession.builder\
                    .config("spark.jars.packages","org.apache.hadoop:hadoop-aws:2.7.0")\
                    .appName("Project: i94")\
                    .getOrCreate()

# %%
sp_sas_data = (spark.read.format("csv")\
                         .options(header="true")\
                         .load("D:/Capstone-Project/Project-Workspace/immigration_data_sample.csv")
              )

# %%
sp_sas_data.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- cicid: string (nullable = true)
#  |-- i94yr: string (nullable = true)
#  |-- i94mon: string (nullable = true)
#  |-- i94cit: string (nullable = true)
#  |-- i94res: string (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: string (nullable = true)
#  |-- i94mode: string (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: string (nullable = true)
#  |-- i94bir: string (nullable = true)
#  |-- i94visa: string (nullable = true)
#  |-- count: string (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- visapost: string (nullable = true)
#  |-- occup: string (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- entdepu: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: string (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- insnum: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
# Create a function that returns the desired string from a timestamp 
def convert_5_digit_sasdate_to_yyyymmdd(sasdate):
    epoch = datetime.datetime(1960, 1, 1)
    return (epoch + datetime.timedelta(days=sasdate)).strftime('%Y%m%d')

# Create the UDF
convert_5_digit_sasdate_to_yyyymmdd_udf = udf(lambda x: convert_5_digit_sasdate_to_yyyymmdd(x))

#print(convert_5_digit_sasdate_to_yyyymmdd(20574.0))

# %%
sp_df = sp_sas_data
sp_df = sp_df.drop("_c0")
# drop columns that CIC does not use
sp_df = sp_df.drop("dtadfile","visapost","occup","entdepa","entdepd","entdepu","dtaddto")
sp_df = sp_df.drop("i94yr","i94mon","insnum","admnum")
sp_df = sp_df.withColumn("arrdate", sp_df["arrdate"].cast(IntegerType()))
sp_df = sp_df.withColumn("depdate", sp_df["depdate"].cast(IntegerType()))
sp_df = sp_df.withColumnRenamed("arrdate", "arr_yyyymmdd")
sp_df = sp_df.withColumnRenamed("depdate", "dep_yyyymmdd")
sp_df = sp_df.withColumnRenamed("count", "i94count")

# %%
sp_df.printSchema()
# Out:
# root
#  |-- cicid: string (nullable = true)
#  |-- i94cit: string (nullable = true)
#  |-- i94res: string (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arr_yyyymmdd: integer (nullable = true)
#  |-- i94mode: string (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- dep_yyyymmdd: integer (nullable = true)
#  |-- i94bir: string (nullable = true)
#  |-- i94visa: string (nullable = true)
#  |-- i94count: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
sp_depdate_nn = sp_df.where(F.col("dep_yyyymmdd").isNotNull())
sp_depdate_nn = sp_depdate_nn.withColumn('arr_yyyymmdd', convert_5_digit_sasdate_to_yyyymmdd_udf(sp_depdate_nn['arr_yyyymmdd']))
sp_depdate_nn = sp_depdate_nn.withColumn('dep_yyyymmdd', convert_5_digit_sasdate_to_yyyymmdd_udf(sp_depdate_nn['dep_yyyymmdd']))

# %%
sp_depdate_nn.createOrReplaceTempView("depdate_nn")
spark.sql("""
select *
from depdate_nn
where 1 = 1
""").show(5)
# Out:
# +---------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# |    cicid|i94cit|i94res|i94port|arr_yyyymmdd|i94mode|i94addr|dep_yyyymmdd|i94bir|i94visa|i94count|matflag|biryear|gender|airline|fltno|visatype|
# +---------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# |4084316.0| 209.0| 209.0|    HHW|    20160422|    1.0|     HI|    20160429|  61.0|    2.0|     1.0|      M| 1955.0|     F|     JL|00782|      WT|
# |4422636.0| 582.0| 582.0|    MCA|    20160423|    1.0|     TX|    20160424|  26.0|    2.0|     1.0|      M| 1990.0|     M|    *GA|XBLNG|      B2|
# |1195600.0| 148.0| 112.0|    OGG|    20160407|    1.0|     FL|    20160427|  76.0|    2.0|     1.0|      M| 1940.0|     M|     LH|00464|      WT|
# |5291768.0| 297.0| 297.0|    LOS|    20160428|    1.0|     CA|    20160507|  25.0|    2.0|     1.0|      M| 1991.0|     M|     QR|00739|      B2|
# | 985523.0| 111.0| 111.0|    CHM|    20160406|    3.0|     NY|    20160409|  19.0|    2.0|     1.0|      M| 1997.0|     F|   null| LAND|      WT|
# +---------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# only showing top 5 rows

# %%
sp_depdate_n = sp_df.where(F.col("dep_yyyymmdd").isNull())
sp_depdate_n = sp_depdate_n.withColumn('arr_yyyymmdd', convert_5_digit_sasdate_to_yyyymmdd_udf(sp_depdate_n['arr_yyyymmdd']))

# %%
sp_depdate_n.createOrReplaceTempView("depdate_n")
spark.sql("""
select *
from depdate_n
where 1 = 1
""").show(5)
# Out:
# +---------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# |    cicid|i94cit|i94res|i94port|arr_yyyymmdd|i94mode|i94addr|dep_yyyymmdd|i94bir|i94visa|i94count|matflag|biryear|gender|airline|fltno|visatype|
# +---------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# | 216657.0| 696.0| 696.0|    FTL|    20160401|    1.0|     FL|        null|  54.0|    2.0|     1.0|   null| 1962.0|     F|     2D|00406|      B2|
# |5957654.0| 254.0| 276.0|    SAI|    20160412|    1.0|     GU|        null|  20.0|    2.0|     1.0|   null| 1996.0|     M|     7C|03404|     GMT|
# |1435383.0| 574.0| 206.0|    BLA|    20160408|    3.0|     NE|        null|  61.0|    2.0|     1.0|   null| 1955.0|     F|   null|01788|      B2|
# |1843262.0| 245.0| 245.0|    CHI|    20160410|    1.0|     IN|        null|  60.0|    2.0|     1.0|   null| 1956.0|     F|     AA|00186|      B2|
# |4231176.0| 586.0| 586.0|    NYC|    20160422|    1.0|     NJ|        null|  68.0|    2.0|     1.0|   null| 1948.0|  null|     AA|02179|      B2|
# +---------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# only showing top 5 rows

# %%
sp_stg_cic = sp_depdate_nn.union(sp_depdate_n)

# %%
sp_stg_cic.createOrReplaceTempView("stg_cic")
spark.sql("""
select count(*)
from stg_cic
where 1 = 1
and dep_yyyymmdd is null
""").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |      49|
# +--------+

# %%
sp_stg_cic.printSchema()
# Out:
# root
#  |-- cicid: string (nullable = true)
#  |-- i94cit: string (nullable = true)
#  |-- i94res: string (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arr_yyyymmdd: string (nullable = true)
#  |-- i94mode: string (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- dep_yyyymmdd: string (nullable = true)
#  |-- i94bir: string (nullable = true)
#  |-- i94visa: string (nullable = true)
#  |-- i94count: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
from pyspark.sql.types import IntegerType
sp_stg_cic = sp_stg_cic.withColumn("cicid", sp_stg_cic["cicid"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("i94cit", sp_stg_cic["i94cit"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("i94res", sp_stg_cic["i94res"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("i94mode", sp_stg_cic["i94mode"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("i94bir", sp_stg_cic["i94bir"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("i94visa", sp_stg_cic["i94visa"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("i94count", sp_stg_cic["i94count"].cast(IntegerType()))
sp_stg_cic = sp_stg_cic.withColumn("biryear", sp_stg_cic["biryear"].cast(IntegerType()))
#sp_stg_cic = sp_stg_cic.withColumn("arr_yyyymmdd", sp_stg_cic["arr_yyyymmdd"].cast(IntegerType()))
#sp_stg_cic = sp_stg_cic.withColumn("dep_yyyymmdd", sp_stg_cic["dep_yyyymmdd"].cast(IntegerType()))

# %%
sp_stg_cic.show(5)
# Out:
# +-------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# |  cicid|i94cit|i94res|i94port|arr_yyyymmdd|i94mode|i94addr|dep_yyyymmdd|i94bir|i94visa|i94count|matflag|biryear|gender|airline|fltno|visatype|
# +-------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# |4084316|   209|   209|    HHW|    20160422|      1|     HI|    20160429|    61|      2|       1|      M|   1955|     F|     JL|00782|      WT|
# |4422636|   582|   582|    MCA|    20160423|      1|     TX|    20160424|    26|      2|       1|      M|   1990|     M|    *GA|XBLNG|      B2|
# |1195600|   148|   112|    OGG|    20160407|      1|     FL|    20160427|    76|      2|       1|      M|   1940|     M|     LH|00464|      WT|
# |5291768|   297|   297|    LOS|    20160428|      1|     CA|    20160507|    25|      2|       1|      M|   1991|     M|     QR|00739|      B2|
# | 985523|   111|   111|    CHM|    20160406|      3|     NY|    20160409|    19|      2|       1|      M|   1997|     F|   null| LAND|      WT|
# +-------+------+------+-------+------------+-------+-------+------------+------+-------+--------+-------+-------+------+-------+-----+--------+
# only showing top 5 rows

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=i94 user=i94user password=Passw0rd")
cur = conn.cursor()

# %%
delete_from_stg_cic = ("""
delete from stg_cic;
""")

# %%
sp_stg_cic.printSchema()
# Out:
# root
#  |-- cicid: integer (nullable = true)
#  |-- i94cit: integer (nullable = true)
#  |-- i94res: integer (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arr_yyyymmdd: string (nullable = true)
#  |-- i94mode: integer (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- dep_yyyymmdd: string (nullable = true)
#  |-- i94bir: integer (nullable = true)
#  |-- i94visa: integer (nullable = true)
#  |-- i94count: integer (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
insert_into_stg_cic = ("""
insert into stg_cic
(
    cicid,
    i94cit,
    i94res,
    i94port,
    arr_yyyymmdd,
    i94mode,
    i94addr,
    dep_yyyymmdd,
    i94bir,
    i94visa,
    i94count,
    matflag,
    biryear,
    gender,
    airline,
    fltno,
    visatype
) values 
(
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s,
# %s
);
""")

# %%
# a function to insert records
def insert_stg_cic_records(cur, stg_cic_df):
    for i, row in stg_cic_df.iterrows():
        #print('i =',i)
        print('row =',row)
        cur.execute(insert_into_stg_cic,row)

# %%
# delete records
cur.execute(delete_from_stg_cic)

# %%
sp_stg_cic.printSchema()
# Out:
# root
#  |-- cicid: integer (nullable = true)
#  |-- i94cit: integer (nullable = true)
#  |-- i94res: integer (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arr_yyyymmdd: string (nullable = true)
#  |-- i94mode: integer (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- dep_yyyymmdd: string (nullable = true)
#  |-- i94bir: integer (nullable = true)
#  |-- i94visa: integer (nullable = true)
#  |-- i94count: integer (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
pd_stg_sic = sp_stg_cic.select("*").toPandas()

# %%
pd_stg_sic.head()
# Out:
#      cicid  i94cit  i94res i94port arr_yyyymmdd  i94mode i94addr dep_yyyymmdd  \
# 0  4084316     209     209     HHW     20160422        1      HI     20160429
# 1  4422636     582     582     MCA     20160423        1      TX     20160424
# 2  1195600     148     112     OGG     20160407        1      FL     20160427
# 3  5291768     297     297     LOS     20160428        1      CA     20160507
# 4   985523     111     111     CHM     20160406        3      NY     20160409
#
#    i94bir  i94visa  i94count matflag  biryear gender airline  fltno visatype
# 0      61        2         1       M     1955      F      JL  00782       WT
# 1      26        2         1       M     1990      M     *GA  XBLNG       B2
# 2      76        2         1       M     1940      M      LH  00464       WT
# 3      25        2         1       M     1991      M      QR  00739       B2
# 4      19        2         1       M     1997      F    None   LAND       WT

# %%
pd_stg_sic[pd_stg_sic['dep_yyyymmdd'].isnull()]
# Out:
#        cicid  i94cit  i94res i94port arr_yyyymmdd  i94mode i94addr  \
# 951   216657     696     696     FTL     20160401        1      FL
# 952  5957654     254     276     SAI     20160412        1      GU
# 953  1435383     574     206     BLA     20160408        3      NE
# 954  1843262     245     245     CHI     20160410        1      IN
# 955  4231176     586     586     NYC     20160422        1      NJ
# 956  4732257     245     245     SFR     20160425        1      CA
# 957  1093165     575     575     MIA     20160406        1      FL
# 958  5913269     438     438     HHW     20160423        2    None
# 959   510204     258     258     CHI     20160403        1      IL
# 960  4700630     135     135     NYC     20160425        1      NY
# 961  5927858     438     438     HHW     20160423        2    None
# 962  5514177     343     343     HOU     20160429        1      TX
# 963  3552753     438     438     BLA     20160419        3      WA
# 964  3886754     213     213     CHI     20160421        1      IL
# 965  2652805     689     689     ATL     20160414        1      FL
# 966    86281     368     368     KOA     20160401        1    None
# 967  1400880     213     213     NEW     20160408        1      NJ
# 968  1624057     213     213     CHI     20160409        1      CA
# 969  4251217     104     104     NEW     20160423        1    None
# 970  1553520     692     692     NYC     20160408        1      NY
# 971  5956950     254     276     AGA     20160414        1      GU
# 972  1401034     213     213     NYC     20160408        1      NY
# 973  6019750     117     135     LOS     20160408        9      NY
# 974  3380572     266     266     LOS     20160418        1      FL
# 975  5827765     582     582     PHO     20160430        1      OK
# 976   499578     245     245     SFR     20160403        1      CA
# 977    54317     209     209     HHW     20160401        1      HI
# 978  5771544     514     514     BAL     20160430        1      MD
# 979  4804280     582     582     DAL     20160425        1      CA
# 980  5902022     112     112     HHW     20160415        9    None
# 981   751451     577     577     OTM     20160404        3      CA
# 982  6034994     252     209     AGA     20160429        1      GU
# 983  2814946     582     582     ONT     20160415        1      CA
# 984  5020169     113     113     NYC     20160427        1      NY
# 985  2892590     123     123     WAS     20160416        1      MD
# 986  3434626     582     582     CHI     20160418        1      IL
# 987  1044320     258     258     NYC     20160406        1      MI
# 988  4106787     258     258     WAS     20160422        1      MA
# 989  4456287     687     687     MIA     20160423        1      FL
# 990   561992     582     582     CHI     20160403        1      IL
# 991  5069811     213     213     BOS     20160427        1      MA
# 992  5928244     438     438     HHW     20160423        2    None
# 993   888522     512     512     FTL     20160405        1      IN
# 994  3360046     213     213     NYC     20160418        1      CT
# 995  5928085     438     438     HHW     20160423        2    None
# 996  3484147     103     103     MIA     20160419        1      FL
# 997  3535501     245     245     NEW     20160419        1      PA
# 998  1032729     213     213     PHI     20160406        1      NJ
# 999  5018908     111     111     MON     20160427        1      FL
#
#     dep_yyyymmdd  i94bir  i94visa  i94count matflag  biryear gender airline  \
# 951         None      54        2         1    None     1962      F      2D
# 952         None      20        2         1    None     1996      M      7C
# 953         None      61        2         1    None     1955      F    None
# 954         None      60        2         1    None     1956      F      AA
# 955         None      68        2         1    None     1948   None      AA
# 956         None      68        2         1    None     1948      M      UA
# 957         None      34        2         1    None     1982      M      AV
# 958         None      61        2         1    None     1955      F    None
# 959         None      59        2         1    None     1957      M      TK
# 960         None      29        2         1    None     1987      F      BA
# 961         None      88        2         1       M     1928      M    None
# 962         None       3        3         1    None     2013      M      EK
# 963         None      24        2         1    None     1992      M    None
# 964         None      78        2         1    None     1938      M      AI
# 965         None      35        2         1    None     1981      M      DL
# 966         None      35        2         1    None     1981      M      SV
# 967         None       2        3         1    None     2014      M      AI
# 968         None      64        2         1    None     1952      F      EK
# 969         None      41        2         1    None     1975      F      UA
# 970         None       1        2         1    None     2015      F      EQ
# 971         None       9        2         1    None     2007      M      LJ
# 972         None      30        2         1    None     1986   None      QR
# 973         None      39        2         1    None     1977      F    None
# 974         None      23        3         1    None     1993      M      UA
# 975         None      59        2         1    None     1957      F      Y4
# 976         None      29        3         1    None     1987      F      UA
# 977         None      28        2         1    None     1988      M      JL
# 978         None      33        3         1    None     1983      M      WN
# 979         None      23        2         1    None     1993      F      Y4
# 980         None      55        2         1    None     1961      X    None
# 981         None      25        2         1    None     1991      M    None
# 982         None      23        2         1    None     1993      M      UA
# 983         None      51        2         1    None     1965      F      AM
# 984         None      33        2         1    None     1983      M      TK
# 985         None      61        1         1    None     1955      F      SK
# 986         None      70        2         1    None     1946      M      Y4
# 987         None      29        2         1    None     1987      F      QR
# 988         None      26        3         1    None     1990      F      QR
# 989         None      32        2         1    None     1984      M      AR
# 990         None      28        2         1    None     1988      M      Y4
# 991         None      70        2         1    None     1946      F      QR
# 992         None      70        2         1       M     1946      M    None
# 993         None      61        2         1    None     1955   None      B6
# 994         None      66        2         1    None     1950      F      AI
# 995         None      74        2         1       M     1942      M    None
# 996         None      63        2         1    None     1953      F      AB
# 997         None      56        2         1    None     1960      F      UA
# 998         None      70        2         1    None     1946      M      BA
# 999         None      60        2         1    None     1956      M      RV
#
#      fltno visatype
# 951  00406       B2
# 952  03404      GMT
# 953  01788       B2
# 954  00186       B2
# 955  02179       B2
# 956  00008       B2
# 957  00310       B2
# 958   None       WT
# 959      5       B2
# 960    117       WT
# 961   None       WT
# 962  00211       F2
# 963   LAND       WT
# 964  00127       B2
# 965  00060       B2
# 966  00023       B2
# 967    191       F2
# 968  00235       B2
# 969  00091       WT
# 970    550       B2
# 971  00641      GMT
# 972  00701       B2
# 973   None       WT
# 974    180       M1
# 975  00902       B2
# 976  00889       F1
# 977  00782       WT
# 978    907       F1
# 979  00892       B2
# 980   None       WT
# 981   LAND       B2
# 982  00827      GMT
# 983  00780       B2
# 984  00003       WT
# 985  00925       WB
# 986  00946       B2
# 987  00701       B2
# 988  00707       F2
# 989  01302       B2
# 990    940       B2
# 991  00743       B2
# 992   None       WT
# 993  02316       B2
# 994  00101       B2
# 995   None       WT
# 996  07000       WT
# 997  00087       B2
# 998  00069       B2
# 999  01606       WT

# %%
# insert records
insert_stg_cic_records(cur, pd_stg_sic)
# Out:
# row = cicid            4084316
# i94cit               209
# i94res               209
# i94port              HHW
# arr_yyyymmdd    20160422
# i94mode                1
# i94addr               HI
# dep_yyyymmdd    20160429
# i94bir                61
# i94visa                2
# i94count               1
# matflag                M
# biryear             1955
# gender                 F
# airline               JL
# fltno              00782
# visatype              WT
# Name: 0, dtype: object
# row = cicid            4422636
# i94cit               582
# i94res               582
# i94port              MCA
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               TX
# dep_yyyymmdd    20160424
# i94bir                26
# i94visa                2
# i94count               1
# matflag                M
# biryear             1990
# gender                 M
# airline              *GA
# fltno              XBLNG
# visatype              B2
# Name: 1, dtype: object
# row = cicid            1195600
# i94cit               148
# i94res               112
# i94port              OGG
# arr_yyyymmdd    20160407
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160427
# i94bir                76
# i94visa                2
# i94count               1
# matflag                M
# biryear             1940
# gender                 M
# airline               LH
# fltno              00464
# visatype              WT
# Name: 2, dtype: object
# row = cicid            5291768
# i94cit               297
# i94res               297
# i94port              LOS
# arr_yyyymmdd    20160428
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160507
# i94bir                25
# i94visa                2
# i94count               1
# matflag                M
# biryear             1991
# gender                 M
# airline               QR
# fltno              00739
# visatype              B2
# Name: 3, dtype: object
# row = cicid             985523
# i94cit               111
# i94res               111
# i94port              CHM
# arr_yyyymmdd    20160406
# i94mode                3
# i94addr               NY
# dep_yyyymmdd    20160409
# i94bir                19
# i94visa                2
# i94count               1
# matflag                M
# biryear             1997
# gender                 F
# airline             None
# fltno               LAND
# visatype              WT
# Name: 4, dtype: object
# row = cicid            1481650
# i94cit               577
# i94res               577
# i94port              ATL
# arr_yyyymmdd    20160408
# i94mode                1
# i94addr               GA
# dep_yyyymmdd    20160601
# i94bir                51
# i94visa                2
# i94count               1
# matflag                M
# biryear             1965
# gender                 M
# airline               DL
# fltno                910
# visatype              B2
# Name: 5, dtype: object
# row = cicid            2197173
# i94cit               245
# i94res               245
# i94port              SFR
# arr_yyyymmdd    20160412
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160630
# i94bir                48
# i94visa                2
# i94count               1
# matflag                M
# biryear             1968
# gender                 F
# airline               CX
# fltno                870
# visatype              B2
# Name: 6, dtype: object
# row = cicid             232708
# i94cit               113
# i94res               135
# i94port              NYC
# arr_yyyymmdd    20160402
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160410
# i94bir                33
# i94visa                2
# i94count               1
# matflag                M
# biryear             1983
# gender                 F
# airline               BA
# fltno              00117
# visatype              WT
# Name: 7, dtype: object
# row = cicid            5227851
# i94cit               131
# i94res               131
# i94port              CHI
# arr_yyyymmdd    20160428
# i94mode                1
# i94addr               IL
# dep_yyyymmdd    20160501
# i94bir                39
# i94visa                2
# i94count               1
# matflag                M
# biryear             1977
# gender              None
# airline               LX
# fltno              00008
# visatype              WT
# Name: 8, dtype: object
# row = cicid              13213
# i94cit               116
# i94res               116
# i94port              LOS
# arr_yyyymmdd    20160401
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160409
# i94bir                35
# i94visa                2
# i94count               1
# matflag                M
# biryear             1981
# gender              None
# airline               AA
# fltno              00109
# visatype              WT
# Name: 9, dtype: object
# row = cicid            1230572
# i94cit               438
# i94res               438
# i94port              LOS
# arr_yyyymmdd    20160407
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160421
# i94bir                 4
# i94visa                2
# i94count               1
# matflag                M
# biryear             2012
# gender                 F
# airline               QF
# fltno              00015
# visatype              WT
# Name: 10, dtype: object
# row = cicid            5056736
# i94cit               209
# i94res               209
# i94port              PHI
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               HI
# dep_yyyymmdd    20160501
# i94bir                72
# i94visa                2
# i94count               1
# matflag                M
# biryear             1944
# gender                 M
# airline               DL
# fltno              00598
# visatype              WT
# Name: 11, dtype: object
# row = cicid            2711583
# i94cit               148
# i94res               112
# i94port              FTL
# arr_yyyymmdd    20160415
# i94mode                2
# i94addr             None
# dep_yyyymmdd    20160421
# i94bir                54
# i94visa                2
# i94count               1
# matflag                M
# biryear             1962
# gender                 F
# airline              VES
# fltno              93724
# visatype              WT
# Name: 12, dtype: object
# row = cicid            4916639
# i94cit               260
# i94res               260
# i94port              LOS
# arr_yyyymmdd    20160426
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160507
# i94bir                62
# i94visa                2
# i94count               1
# matflag                M
# biryear             1954
# gender                 F
# airline               EK
# fltno              00215
# visatype              B2
# Name: 13, dtype: object
# row = cicid            1387607
# i94cit               148
# i94res               112
# i94port              BOS
# arr_yyyymmdd    20160408
# i94mode                1
# i94addr               MA
# dep_yyyymmdd    20160416
# i94bir                34
# i94visa                2
# i94count               1
# matflag                M
# biryear             1982
# gender                 F
# airline               AF
# fltno              00338
# visatype              WT
# Name: 14, dtype: object
# row = cicid            5960799
# i94cit               245
# i94res               245
# i94port              SAI
# arr_yyyymmdd    20160401
# i94mode                1
# i94addr             None
# dep_yyyymmdd    20160406
# i94bir                30
# i94visa                2
# i94count               1
# matflag                M
# biryear             1986
# gender                 M
# airline               MU
# fltno              00763
# visatype              CP
# Name: 15, dtype: object
# row = cicid            1056530
# i94cit               512
# i94res               512
# i94port              NAS
# arr_yyyymmdd    20160406
# i94mode                1
# i94addr               GA
# dep_yyyymmdd    20160408
# i94bir                21
# i94visa                2
# i94count               1
# matflag                M
# biryear             1995
# gender                 F
# airline               DL
# fltno              00554
# visatype              B2
# Name: 16, dtype: object
# row = cicid            2466971
# i94cit               689
# i94res               689
# i94port              FTL
# arr_yyyymmdd    20160413
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160425
# i94bir                43
# i94visa                2
# i94count               1
# matflag                M
# biryear             1973
# gender              None
# airline               AD
# fltno              08704
# visatype              B2
# Name: 17, dtype: object
# row = cicid            4668286
# i94cit               746
# i94res               158
# i94port              SEA
# arr_yyyymmdd    20160424
# i94mode                1
# i94addr               NV
# dep_yyyymmdd    20160427
# i94bir                46
# i94visa                2
# i94count               1
# matflag                M
# biryear             1970
# gender                 M
# airline               DL
# fltno              00143
# visatype              B2
# Name: 18, dtype: object
# row = cicid            2556646
# i94cit               260
# i94res               260
# i94port              FTL
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160522
# i94bir                14
# i94visa                2
# i94count               1
# matflag                M
# biryear             2002
# gender                 M
# airline               OZ
# fltno              00204
# visatype              B2
# Name: 19, dtype: object
# row = cicid            4042798
# i94cit               115
# i94res               115
# i94port              ORL
# arr_yyyymmdd    20160422
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160514
# i94bir                62
# i94visa                2
# i94count               1
# matflag                M
# biryear             1954
# gender              None
# airline               FI
# fltno              00689
# visatype              WT
# Name: 20, dtype: object
# row = cicid            2139030
# i94cit               689
# i94res               689
# i94port              PSP
# arr_yyyymmdd    20160411
# i94mode                1
# i94addr               HI
# dep_yyyymmdd    20160424
# i94bir                40
# i94visa                2
# i94count               1
# matflag                M
# biryear             1976
# gender              None
# airline               AA
# fltno              00962
# visatype              B2
# Name: 21, dtype: object
# row = cicid            3097076
# i94cit               111
# i94res               511
# i94port              NYC
# arr_yyyymmdd    20160417
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160423
# i94bir                41
# i94visa                2
# i94count               1
# matflag                M
# biryear             1975
# gender                 F
# airline               DY
# fltno              06750
# visatype              WT
# Name: 22, dtype: object
# row = cicid            2741251
# i94cit               251
# i94res               251
# i94port              HOU
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160430
# i94bir                22
# i94visa                2
# i94count               1
# matflag                M
# biryear             1994
# gender                 M
# airline               BA
# fltno              00273
# visatype              B2
# Name: 23, dtype: object
# row = cicid            2721962
# i94cit               209
# i94res               209
# i94port              NEW
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               HI
# dep_yyyymmdd    20160418
# i94bir                41
# i94visa                2
# i94count               1
# matflag                M
# biryear             1975
# gender              None
# airline               HA
# fltno              00458
# visatype              WT
# Name: 24, dtype: object
# row = cicid             513779
# i94cit               268
# i94res               268
# i94port              SFR
# arr_yyyymmdd    20160403
# i94mode                1
# i94addr               TX
# dep_yyyymmdd    20160605
# i94bir                33
# i94visa                2
# i94count               1
# matflag                M
# biryear             1983
# gender                 F
# airline               UA
# fltno              00872
# visatype              WT
# Name: 25, dtype: object
# row = cicid            3669540
# i94cit               129
# i94res               585
# i94port              BAL
# arr_yyyymmdd    20160420
# i94mode                1
# i94addr             None
# dep_yyyymmdd    20160502
# i94bir                22
# i94visa                2
# i94count               1
# matflag                M
# biryear             1994
# gender                 M
# airline               WN
# fltno              00812
# visatype              WT
# Name: 26, dtype: object
# row = cicid            5070551
# i94cit               213
# i94res               213
# i94port              LOS
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160810
# i94bir                64
# i94visa                2
# i94count               1
# matflag                M
# biryear             1952
# gender                 M
# airline               QR
# fltno              00739
# visatype              B2
# Name: 27, dtype: object
# row = cicid            2006623
# i94cit               135
# i94res               135
# i94port              ORL
# arr_yyyymmdd    20160411
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160425
# i94bir                17
# i94visa                2
# i94count               1
# matflag                M
# biryear             1999
# gender                 M
# airline               VS
# fltno              00075
# visatype              WT
# Name: 28, dtype: object
# row = cicid            2826530
# i94cit               582
# i94res               582
# i94port              SNJ
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160417
# i94bir                42
# i94visa                2
# i94count               1
# matflag                M
# biryear             1974
# gender                 F
# airline               Y4
# fltno              00930
# visatype              B2
# Name: 29, dtype: object
# row = cicid            5692439
# i94cit               133
# i94res               264
# i94port              HOU
# arr_yyyymmdd    20160430
# i94mode                1
# i94addr               NV
# dep_yyyymmdd    20160506
# i94bir                41
# i94visa                1
# i94count               1
# matflag                M
# biryear             1975
# gender                 M
# airline               TK
# fltno              00033
# visatype              B1
# Name: 30, dtype: object
# row = cicid            5835717
# i94cit               582
# i94res               582
# i94port              DET
# arr_yyyymmdd    20160430
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160507
# i94bir                35
# i94visa                2
# i94count               1
# matflag                M
# biryear             1981
# gender                 F
# airline               AA
# fltno              01498
# visatype              B2
# Name: 31, dtype: object
# row = cicid            2752883
# i94cit               373
# i94res               509
# i94port              DET
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160418
# i94bir                34
# i94visa                2
# i94count               1
# matflag                M
# biryear             1982
# gender                 M
# airline               AA
# fltno              01428
# visatype              B2
# Name: 32, dtype: object
# row = cicid             239999
# i94cit               126
# i94res               324
# i94port              FTL
# arr_yyyymmdd    20160402
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160407
# i94bir                16
# i94visa                2
# i94count               1
# matflag                M
# biryear             2000
# gender                 F
# airline               IB
# fltno              06253
# visatype              WT
# Name: 33, dtype: object
# row = cicid            4805034
# i94cit               582
# i94res               582
# i94port              HOU
# arr_yyyymmdd    20160425
# i94mode                1
# i94addr               PA
# dep_yyyymmdd    20160429
# i94bir                40
# i94visa                1
# i94count               1
# matflag                M
# biryear             1976
# gender                 F
# airline               UA
# fltno              01085
# visatype              B1
# Name: 34, dtype: object
# row = cicid            6055103
# i94cit               252
# i94res               209
# i94port              AGA
# arr_yyyymmdd    20160428
# i94mode                1
# i94addr               GU
# dep_yyyymmdd    20160503
# i94bir                27
# i94visa                2
# i94count               1
# matflag                M
# biryear             1989
# gender                 M
# airline               TW
# fltno              00311
# visatype             GMT
# Name: 35, dtype: object
# row = cicid            2495693
# i94cit               117
# i94res               117
# i94port              NYC
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160416
# i94bir                34
# i94visa                1
# i94count               1
# matflag                M
# biryear             1982
# gender              None
# airline               S3
# fltno              01515
# visatype              WB
# Name: 36, dtype: object
# row = cicid            2929149
# i94cit               213
# i94res               213
# i94port              LVG
# arr_yyyymmdd    20160416
# i94mode                1
# i94addr               NC
# dep_yyyymmdd    20160629
# i94bir                61
# i94visa                2
# i94count               1
# matflag                M
# biryear             1955
# gender                 M
# airline               LH
# fltno              00428
# visatype              B2
# Name: 37, dtype: object
# row = cicid            4462449
# i94cit               689
# i94res               689
# i94port              ORL
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160506
# i94bir                26
# i94visa                2
# i94count               1
# matflag                M
# biryear             1990
# gender                 F
# airline               DL
# fltno              00196
# visatype              B2
# Name: 38, dtype: object
# row = cicid             800571
# i94cit               687
# i94res               687
# i94port              PSP
# arr_yyyymmdd    20160404
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160426
# i94bir                56
# i94visa                2
# i94count               1
# matflag                M
# biryear             1960
# gender                 M
# airline               AR
# fltno              01304
# visatype              B2
# Name: 39, dtype: object
# row = cicid             692716
# i94cit               245
# i94res               245
# i94port              NEW
# arr_yyyymmdd    20160404
# i94mode                1
# i94addr               NJ
# dep_yyyymmdd    20160716
# i94bir                32
# i94visa                1
# i94count               1
# matflag                M
# biryear             1984
# gender                 M
# airline               CA
# fltno              00819
# visatype              B1
# Name: 40, dtype: object
# row = cicid            5472659
# i94cit               209
# i94res               209
# i94port              NEW
# arr_yyyymmdd    20160429
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160505
# i94bir                 8
# i94visa                2
# i94count               1
# matflag                M
# biryear             2008
# gender                 M
# airline               UA
# fltno              00078
# visatype              WT
# Name: 41, dtype: object
# row = cicid             999282
# i94cit               129
# i94res               129
# i94port              MIA
# arr_yyyymmdd    20160406
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160409
# i94bir                59
# i94visa                1
# i94count               1
# matflag                M
# biryear             1957
# gender                 M
# airline               AM
# fltno              00428
# visatype              WB
# Name: 42, dtype: object
# row = cicid            2572618
# i94cit               528
# i94res               528
# i94port              MIA
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160418
# i94bir                38
# i94visa                2
# i94count               1
# matflag                M
# biryear             1978
# gender                 M
# airline               AA
# fltno              01504
# visatype              B2
# Name: 43, dtype: object
# row = cicid            4269184
# i94cit               123
# i94res               123
# i94port              NEW
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160506
# i94bir                43
# i94visa                2
# i94count               1
# matflag                M
# biryear             1973
# gender                 M
# airline               UA
# fltno              00017
# visatype              WT
# Name: 44, dtype: object
# row = cicid             861557
# i94cit               209
# i94res               209
# i94port              SDP
# arr_yyyymmdd    20160405
# i94mode                1
# i94addr             None
# dep_yyyymmdd    20160408
# i94bir                46
# i94visa                2
# i94count               1
# matflag                M
# biryear             1970
# gender                 M
# airline               JL
# fltno              00066
# visatype              WT
# Name: 45, dtype: object
# row = cicid            2863583
# i94cit               689
# i94res               689
# i94port              MIA
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160425
# i94bir                10
# i94visa                2
# i94count               1
# matflag                M
# biryear             2006
# gender                 F
# airline               JJ
# fltno              08094
# visatype              B2
# Name: 46, dtype: object
# row = cicid            5973747
# i94cit               252
# i94res               209
# i94port              SAI
# arr_yyyymmdd    20160408
# i94mode                1
# i94addr             None
# dep_yyyymmdd    20160410
# i94bir                65
# i94visa                2
# i94count               1
# matflag                M
# biryear             1951
# gender                 M
# airline               DL
# fltno              00298
# visatype             GMT
# Name: 47, dtype: object
# row = cicid            4842142
# i94cit               689
# i94res               689
# i94port              ORL
# arr_yyyymmdd    20160425
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160504
# i94bir                34
# i94visa                2
# i94count               1
# matflag                M
# biryear             1982
# gender                 M
# airline               DL
# fltno              00196
# visatype              B2
# Name: 48, dtype: object
# row = cicid            2955388
# i94cit               438
# i94res               438
# i94port              VCV
# arr_yyyymmdd    20160416
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160423
# i94bir                46
# i94visa                1
# i94count               1
# matflag                M
# biryear             1970
# gender              None
# airline               UA
# fltno              00595
# visatype              WB
# Name: 49, dtype: object
# row = cicid            1592228
# i94cit               135
# i94res               135
# i94port              DUB
# arr_yyyymmdd    20160409
# i94mode                1
# i94addr               VT
# dep_yyyymmdd    20160418
# i94bir                52
# i94visa                2
# i94count               1
# matflag                M
# biryear             1964
# gender                 F
# airline               EI
# fltno              00139
# visatype              WT
# Name: 50, dtype: object
# row = cicid            3108700
# i94cit               129
# i94res               129
# i94port              BOS
# arr_yyyymmdd    20160417
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160503
# i94bir                33
# i94visa                2
# i94count               1
# matflag                M
# biryear             1983
# gender                 M
# airline               IB
# fltno              06165
# visatype              WT
# Name: 51, dtype: object
# row = cicid            5287221
# i94cit               258
# i94res               258
# i94port              PEM
# arr_yyyymmdd    20160428
# i94mode                3
# i94addr               IL
# dep_yyyymmdd    20160912
# i94bir                25
# i94visa                2
# i94count               1
# matflag                M
# biryear             1991
# gender                 M
# airline             None
# fltno               LAND
# visatype              B2
# Name: 52, dtype: object
# row = cicid            4455709
# i94cit               687
# i94res               687
# i94port              NYC
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160429
# i94bir                19
# i94visa                2
# i94count               1
# matflag                M
# biryear             1997
# gender                 M
# airline               AR
# fltno              01300
# visatype              B2
# Name: 53, dtype: object
# row = cicid              36661
# i94cit               135
# i94res               135
# i94port              LOS
# arr_yyyymmdd    20160401
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160614
# i94bir                31
# i94visa                2
# i94count               1
# matflag                M
# biryear             1985
# gender                 M
# airline               NZ
# fltno                  6
# visatype              B2
# Name: 54, dtype: object
# row = cicid            2655122
# i94cit               689
# i94res               689
# i94port              LOS
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160428
# i94bir                58
# i94visa                2
# i94count               1
# matflag                M
# biryear             1958
# gender                 M
# airline               CM
# fltno              00302
# visatype              B2
# Name: 55, dtype: object
# row = cicid            2873671
# i94cit               746
# i94res               158
# i94port              NYC
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               MA
# dep_yyyymmdd    20160501
# i94bir                66
# i94visa                2
# i94count               1
# matflag                M
# biryear             1950
# gender                 M
# airline               SU
# fltno              00102
# visatype              B2
# Name: 56, dtype: object
# row = cicid            2053392
# i94cit               438
# i94res               438
# i94port              LOS
# arr_yyyymmdd    20160411
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160412
# i94bir                28
# i94visa                2
# i94count               1
# matflag                M
# biryear             1988
# gender              None
# airline               NZ
# fltno              00006
# visatype              WT
# Name: 57, dtype: object
# row = cicid             450692
# i94cit               123
# i94res               123
# i94port              NEW
# arr_yyyymmdd    20160403
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160420
# i94bir                34
# i94visa                2
# i94count               1
# matflag                M
# biryear             1982
# gender                 F
# airline               UA
# fltno              00071
# visatype              WT
# Name: 58, dtype: object
# row = cicid            1840249
# i94cit               213
# i94res               213
# i94port              SEA
# arr_yyyymmdd    20160410
# i94mode                1
# i94addr               WA
# dep_yyyymmdd    20160515
# i94bir                68
# i94visa                2
# i94count               1
# matflag                M
# biryear             1948
# gender                 F
# airline               EK
# fltno              00227
# visatype              B2
# Name: 59, dtype: object
# row = cicid            4086972
# i94cit               209
# i94res               209
# i94port              SFR
# arr_yyyymmdd    20160422
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160503
# i94bir                44
# i94visa                2
# i94count               1
# matflag                M
# biryear             1972
# gender                 F
# airline               UA
# fltno              00876
# visatype              WT
# Name: 60, dtype: object
# row = cicid            2686134
# i94cit               123
# i94res               123
# i94port              NYC
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160420
# i94bir                21
# i94visa                2
# i94count               1
# matflag                M
# biryear             1995
# gender                 F
# airline               FI
# fltno              00615
# visatype              WT
# Name: 61, dtype: object
# row = cicid            4299497
# i94cit               148
# i94res               112
# i94port              NYC
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160430
# i94bir                31
# i94visa                2
# i94count               1
# matflag                M
# biryear             1985
# gender                 F
# airline               AF
# fltno              00010
# visatype              WT
# Name: 62, dtype: object
# row = cicid            6030826
# i94cit               252
# i94res               209
# i94port              AGA
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               GU
# dep_yyyymmdd    20160426
# i94bir                33
# i94visa                2
# i94count               1
# matflag                M
# biryear             1983
# gender                 M
# airline               UA
# fltno              00150
# visatype             GMT
# Name: 63, dtype: object
# row = cicid            3148387
# i94cit               209
# i94res               209
# i94port              TAM
# arr_yyyymmdd    20160417
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160421
# i94bir                35
# i94visa                1
# i94count               1
# matflag                M
# biryear             1981
# gender                 M
# airline               UA
# fltno              00838
# visatype              WB
# Name: 64, dtype: object
# row = cicid            1787495
# i94cit               111
# i94res               111
# i94port              MIA
# arr_yyyymmdd    20160410
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160419
# i94bir                29
# i94visa                2
# i94count               1
# matflag                M
# biryear             1987
# gender              None
# airline               LA
# fltno              03502
# visatype              WT
# Name: 65, dtype: object
# row = cicid            2522724
# i94cit               148
# i94res               112
# i94port              NEW
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160418
# i94bir                36
# i94visa                2
# i94count               1
# matflag                M
# biryear             1980
# gender                 F
# airline               LH
# fltno              00402
# visatype              WT
# Name: 66, dtype: object
# row = cicid            3293058
# i94cit               691
# i94res               691
# i94port              MIA
# arr_yyyymmdd    20160417
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160421
# i94bir                42
# i94visa                1
# i94count               1
# matflag                M
# biryear             1974
# gender                 M
# airline               AV
# fltno              00030
# visatype              B1
# Name: 67, dtype: object
# row = cicid            4507487
# i94cit               135
# i94res               135
# i94port              ORL
# arr_yyyymmdd    20160424
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160508
# i94bir                12
# i94visa                2
# i94count               1
# matflag                M
# biryear             2004
# gender                 M
# airline               BA
# fltno              02039
# visatype              WT
# Name: 68, dtype: object
# row = cicid            3599863
# i94cit               582
# i94res               582
# i94port              HOU
# arr_yyyymmdd    20160419
# i94mode                1
# i94addr               TX
# dep_yyyymmdd    20160704
# i94bir                42
# i94visa                3
# i94count               1
# matflag                M
# biryear             1974
# gender                 F
# airline               WN
# fltno              02831
# visatype              F1
# Name: 69, dtype: object
# row = cicid             832555
# i94cit               130
# i94res               130
# i94port              NEW
# arr_yyyymmdd    20160405
# i94mode                1
# i94addr             None
# dep_yyyymmdd    20160406
# i94bir                60
# i94visa                2
# i94count               1
# matflag                M
# biryear             1956
# gender                 M
# airline               UA
# fltno              01625
# visatype              WT
# Name: 70, dtype: object
# row = cicid            2351028
# i94cit               209
# i94res               209
# i94port              FTL
# arr_yyyymmdd    20160413
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160416
# i94bir                60
# i94visa                2
# i94count               1
# matflag                M
# biryear             1956
# gender                 M
# airline               JL
# fltno              00066
# visatype              WT
# Name: 71, dtype: object
# row = cicid            4032526
# i94cit               107
# i94res               107
# i94port              BOS
# arr_yyyymmdd    20160422
# i94mode                1
# i94addr               MA
# dep_yyyymmdd    20160507
# i94bir                18
# i94visa                2
# i94count               1
# matflag                M
# biryear             1998
# gender                 F
# airline               LH
# fltno              00420
# visatype              B2
# Name: 72, dtype: object
# row = cicid            5418580
# i94cit               103
# i94res               103
# i94port              SFR
# arr_yyyymmdd    20160429
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160507
# i94bir                44
# i94visa                2
# i94count               1
# matflag                M
# biryear             1972
# gender                 F
# airline               TK
# fltno              00079
# visatype              B2
# Name: 73, dtype: object
# row = cicid             243918
# i94cit               130
# i94res               130
# i94port              PSP
# arr_yyyymmdd    20160402
# i94mode                1
# i94addr               IL
# dep_yyyymmdd    20160404
# i94bir                72
# i94visa                1
# i94count               1
# matflag                M
# biryear             1944
# gender                 M
# airline               RS
# fltno              07597
# visatype              WB
# Name: 74, dtype: object
# row = cicid            1186211
# i94cit               135
# i94res               135
# i94port              ORL
# arr_yyyymmdd    20160407
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160419
# i94bir                46
# i94visa                2
# i94count               1
# matflag                M
# biryear             1970
# gender                 M
# airline               VS
# fltno              00015
# visatype              WT
# Name: 75, dtype: object
# row = cicid            4469436
# i94cit               694
# i94res               694
# i94port              MIA
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160502
# i94bir                63
# i94visa                2
# i94count               1
# matflag                M
# biryear             1953
# gender                 F
# airline               AV
# fltno              00342
# visatype              B2
# Name: 76, dtype: object
# row = cicid            5234881
# i94cit               135
# i94res               135
# i94port              LVG
# arr_yyyymmdd    20160428
# i94mode                1
# i94addr               NE
# dep_yyyymmdd    20160501
# i94bir                40
# i94visa                2
# i94count               1
# matflag                M
# biryear             1976
# gender                 F
# airline               VS
# fltno              00085
# visatype              WT
# Name: 77, dtype: object
# row = cicid            4243216
# i94cit               691
# i94res               691
# i94port              NYC
# arr_yyyymmdd    20160422
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160428
# i94bir                34
# i94visa                2
# i94count               1
# matflag                M
# biryear             1982
# gender                 F
# airline               AV
# fltno              00020
# visatype              B2
# Name: 78, dtype: object
# row = cicid            2324901
# i94cit               131
# i94res               131
# i94port              NYC
# arr_yyyymmdd    20160413
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160425
# i94bir                64
# i94visa                2
# i94count               1
# matflag                M
# biryear             1952
# gender              None
# airline               LX
# fltno              00014
# visatype              WT
# Name: 79, dtype: object
# row = cicid            2887088
# i94cit               111
# i94res               111
# i94port              MIA
# arr_yyyymmdd    20160416
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160424
# i94bir                42
# i94visa                2
# i94count               1
# matflag                M
# biryear             1974
# gender              None
# airline               IB
# fltno              06123
# visatype              WT
# Name: 80, dtype: object
# row = cicid            3335777
# i94cit               135
# i94res               135
# i94port              LOS
# arr_yyyymmdd    20160418
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160501
# i94bir                50
# i94visa                2
# i94count               1
# matflag                M
# biryear             1966
# gender                 M
# airline               BA
# fltno              00283
# visatype              WT
# Name: 81, dtype: object
# row = cicid            1860945
# i94cit               368
# i94res               368
# i94port              WAS
# arr_yyyymmdd    20160410
# i94mode                1
# i94addr               VA
# dep_yyyymmdd    20160531
# i94bir                65
# i94visa                2
# i94count               1
# matflag                M
# biryear             1951
# gender                 F
# airline               UA
# fltno              00988
# visatype              B2
# Name: 82, dtype: object
# row = cicid            3371259
# i94cit               251
# i94res               251
# i94port              KOA
# arr_yyyymmdd    20160418
# i94mode                1
# i94addr               TX
# dep_yyyymmdd    20160510
# i94bir                24
# i94visa                2
# i94count               1
# matflag                M
# biryear             1992
# gender              None
# airline               AA
# fltno              01601
# visatype              B2
# Name: 83, dtype: object
# row = cicid            1905596
# i94cit               575
# i94res               575
# i94port              TAM
# arr_yyyymmdd    20160410
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160416
# i94bir                29
# i94visa                2
# i94count               1
# matflag                M
# biryear             1987
# gender                 M
# airline               CM
# fltno              00228
# visatype              B2
# Name: 84, dtype: object
# row = cicid            2138291
# i94cit               687
# i94res               687
# i94port              MIA
# arr_yyyymmdd    20160411
# i94mode                1
# i94addr               FL
# dep_yyyymmdd    20160428
# i94bir                51
# i94visa                2
# i94count               1
# matflag                M
# biryear             1965
# gender                 M
# airline               JJ
# fltno              08090
# visatype              B2
# Name: 85, dtype: object
# row = cicid            1636545
# i94cit               254
# i94res               276
# i94port              SFR
# arr_yyyymmdd    20160409
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160417
# i94bir                60
# i94visa                2
# i94count               1
# matflag                M
# biryear             1956
# gender                 F
# airline               KE
# fltno              00023
# visatype              WT
# Name: 86, dtype: object
# row = cicid            5270355
# i94cit               213
# i94res               213
# i94port              DAL
# arr_yyyymmdd    20160428
# i94mode                1
# i94addr               TX
# dep_yyyymmdd    20160531
# i94bir                42
# i94visa                2
# i94count               1
# matflag                M
# biryear             1974
# gender                 F
# airline               AA
# fltno              00071
# visatype              B2
# Name: 87, dtype: object
# row = cicid            5695448
# i94cit               135
# i94res               135
# i94port              WAS
# arr_yyyymmdd    20160430
# i94mode                1
# i94addr               VA
# dep_yyyymmdd    20160511
# i94bir                52
# i94visa                2
# i94count               1
# matflag                M
# biryear             1964
# gender                 M
# airline               UA
# fltno              00925
# visatype              WT
# Name: 88, dtype: object
# row = cicid            5021687
# i94cit               116
# i94res               116
# i94port              SHA
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160511
# i94bir                25
# i94visa                2
# i94count               1
# matflag                M
# biryear             1991
# gender                 F
# airline               EI
# fltno              00111
# visatype              WT
# Name: 89, dtype: object
# row = cicid            3681899
# i94cit               135
# i94res               135
# i94port              SFR
# arr_yyyymmdd    20160420
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160501
# i94bir                 6
# i94visa                2
# i94count               1
# matflag                M
# biryear             2010
# gender                 F
# airline               BA
# fltno              00287
# visatype              WT
# Name: 90, dtype: object
# row = cicid              95870
# i94cit               528
# i94res               528
# i94port              NYC
# arr_yyyymmdd    20160401
# i94mode                1
# i94addr               IL
# dep_yyyymmdd    20160405
# i94bir                73
# i94visa                1
# i94count               1
# matflag                M
# biryear             1943
# gender                 M
# airline               AA
# fltno              00956
# visatype              B1
# Name: 91, dtype: object
# row = cicid            2653900
# i94cit               689
# i94res               689
# i94port              MIA
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               GA
# dep_yyyymmdd    20160417
# i94bir                43
# i94visa                1
# i94count               1
# matflag                M
# biryear             1973
# gender                 M
# airline               AA
# fltno              00992
# visatype              B1
# Name: 92, dtype: object
# row = cicid            2002746
# i94cit               135
# i94res               135
# i94port              NYC
# arr_yyyymmdd    20160411
# i94mode                1
# i94addr               NY
# dep_yyyymmdd    20160413
# i94bir                63
# i94visa                1
# i94count               1
# matflag                M
# biryear             1953
# gender                 M
# airline               BA
# fltno              00115
# visatype              WB
# Name: 93, dtype: object
# row = cicid             289809
# i94cit               245
# i94res               245
# i94port              SAI
# arr_yyyymmdd    20160402
# i94mode                1
# i94addr               MP
# dep_yyyymmdd    20160409
# i94bir                29
# i94visa                2
# i94count               1
# matflag                M
# biryear             1987
# gender                 M
# airline               OZ
# fltno              00625
# visatype              B2
# Name: 94, dtype: object
# row = cicid            4969309
# i94cit               582
# i94res               582
# i94port              ATL
# arr_yyyymmdd    20160426
# i94mode                1
# i94addr               VA
# dep_yyyymmdd    20160512
# i94bir                73
# i94visa                2
# i94count               1
# matflag                M
# biryear             1943
# gender                 M
# airline               EV
# fltno              05510
# visatype              B2
# Name: 95, dtype: object
# row = cicid            3364934
# i94cit               245
# i94res               245
# i94port              PSP
# arr_yyyymmdd    20160418
# i94mode                1
# i94addr               HI
# dep_yyyymmdd    20160501
# i94bir                58
# i94visa                2
# i94count               1
# matflag                M
# biryear             1958
# gender              None
# airline               MU
# fltno              00571
# visatype              B2
# Name: 96, dtype: object
# row = cicid            6053964
# i94cit               252
# i94res               209
# i94port              AGA
# arr_yyyymmdd    20160402
# i94mode                1
# i94addr               GU
# dep_yyyymmdd    20160509
# i94bir                 6
# i94visa                2
# i94count               1
# matflag                M
# biryear             2010
# gender                 M
# airline               JL
# fltno              00473
# visatype             GMT
# Name: 97, dtype: object
# row = cicid            2027276
# i94cit               209
# i94res               209
# i94port              SFR
# arr_yyyymmdd    20160411
# i94mode                1
# i94addr               MO
# dep_yyyymmdd    20160418
# i94bir                71
# i94visa                2
# i94count               1
# matflag                M
# biryear             1945
# gender                 F
# airline               UA
# fltno              00034
# visatype              WT
# Name: 98, dtype: object
# row = cicid             650850
# i94cit               130
# i94res               130
# i94port              ATL
# arr_yyyymmdd    20160404
# i94mode                1
# i94addr               GA
# dep_yyyymmdd    20160421
# i94bir                66
# i94visa                2
# i94count               1
# matflag                M
# biryear             1950
# gender                 M
# airline               KL
# fltno              00621
# visatype              WT
# Name: 99, dtype: object
# row = cicid            2926213
# i94cit               209
# i94res               209
# i94port              SPM
# arr_yyyymmdd    20160416
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160422
# i94bir                50
# i94visa                1
# i94count               1
# matflag                M
# biryear             1966
# gender                 M
# airline               UA
# fltno              00034
# visatype              WB
# Name: 100, dtype: object
# row = cicid            2892078
# i94cit               117
# i94res               117
# i94port              NIA
# arr_yyyymmdd    20160416
# i94mode                3
# i94addr               NY
# dep_yyyymmdd    20160419
# i94bir                17
# i94visa                2
# i94count               1
# matflag                M
# biryear             1999
# gender              None
# airline             None
# fltno              00419
# visatype              WT
# Name: 101, dtype: object
# row = cicid            3172408
# i94cit               254
# i94res               276
# i94port              PHR
# arr_yyyymmdd    20160417
# i94mode                3
# i94addr               TX
# dep_yyyymmdd    20160515
# i94bir                36
# i94visa                2
# i94count               1
# matflag                M
# biryear             1980
# gender                 M
# airline             None
# fltno               LAND
# visatype              WT
# Name: 102, dtype: object
# row = cicid            5044435
# i94cit               135
# i94res               135
# i94port              MIA
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               MI
# dep_yyyymmdd    20160504
# i94bir                48
# i94visa                2
# i94count               1
# matflag                M
# biryear             1968
# gender                 F
# airline               AA
# fltno              01089
# visatype              WT
# Name: 103, dtype: object
# row = cicid            5756066
# i94cit               260
# i94res               260
# i94port              BLA
# arr_yyyymmdd    20160430
# i94mode                3
# i94addr               OR
# dep_yyyymmdd    20160502
# i94bir                58
# i94visa                2
# i94count               1
# matflag                M
# biryear             1958
# gender                 F
# airline             None
# fltno               LAND
# visatype              B2
# Name: 104, dtype: object
# row = cicid            1028660
# i94cit               209
# i94res               209
# i94port              MIL
# arr_yyyymmdd    20160406
# i94mode                1
# i94addr               CA
# dep_yyyymmdd    20160409
# ...
# Name: 964, dtype: object
# row = cicid            2652805
# i94cit               689
# i94res               689
# i94port              ATL
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               FL
# dep_yyyymmdd        None
# i94bir                35
# i94visa                2
# i94count               1
# matflag             None
# biryear             1981
# gender                 M
# airline               DL
# fltno              00060
# visatype              B2
# Name: 965, dtype: object
# row = cicid              86281
# i94cit               368
# i94res               368
# i94port              KOA
# arr_yyyymmdd    20160401
# i94mode                1
# i94addr             None
# dep_yyyymmdd        None
# i94bir                35
# i94visa                2
# i94count               1
# matflag             None
# biryear             1981
# gender                 M
# airline               SV
# fltno              00023
# visatype              B2
# Name: 966, dtype: object
# row = cicid            1400880
# i94cit               213
# i94res               213
# i94port              NEW
# arr_yyyymmdd    20160408
# i94mode                1
# i94addr               NJ
# dep_yyyymmdd        None
# i94bir                 2
# i94visa                3
# i94count               1
# matflag             None
# biryear             2014
# gender                 M
# airline               AI
# fltno                191
# visatype              F2
# Name: 967, dtype: object
# row = cicid            1624057
# i94cit               213
# i94res               213
# i94port              CHI
# arr_yyyymmdd    20160409
# i94mode                1
# i94addr               CA
# dep_yyyymmdd        None
# i94bir                64
# i94visa                2
# i94count               1
# matflag             None
# biryear             1952
# gender                 F
# airline               EK
# fltno              00235
# visatype              B2
# Name: 968, dtype: object
# row = cicid            4251217
# i94cit               104
# i94res               104
# i94port              NEW
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr             None
# dep_yyyymmdd        None
# i94bir                41
# i94visa                2
# i94count               1
# matflag             None
# biryear             1975
# gender                 F
# airline               UA
# fltno              00091
# visatype              WT
# Name: 969, dtype: object
# row = cicid            1553520
# i94cit               692
# i94res               692
# i94port              NYC
# arr_yyyymmdd    20160408
# i94mode                1
# i94addr               NY
# dep_yyyymmdd        None
# i94bir                 1
# i94visa                2
# i94count               1
# matflag             None
# biryear             2015
# gender                 F
# airline               EQ
# fltno                550
# visatype              B2
# Name: 970, dtype: object
# row = cicid            5956950
# i94cit               254
# i94res               276
# i94port              AGA
# arr_yyyymmdd    20160414
# i94mode                1
# i94addr               GU
# dep_yyyymmdd        None
# i94bir                 9
# i94visa                2
# i94count               1
# matflag             None
# biryear             2007
# gender                 M
# airline               LJ
# fltno              00641
# visatype             GMT
# Name: 971, dtype: object
# row = cicid            1401034
# i94cit               213
# i94res               213
# i94port              NYC
# arr_yyyymmdd    20160408
# i94mode                1
# i94addr               NY
# dep_yyyymmdd        None
# i94bir                30
# i94visa                2
# i94count               1
# matflag             None
# biryear             1986
# gender              None
# airline               QR
# fltno              00701
# visatype              B2
# Name: 972, dtype: object
# row = cicid            6019750
# i94cit               117
# i94res               135
# i94port              LOS
# arr_yyyymmdd    20160408
# i94mode                9
# i94addr               NY
# dep_yyyymmdd        None
# i94bir                39
# i94visa                2
# i94count               1
# matflag             None
# biryear             1977
# gender                 F
# airline             None
# fltno               None
# visatype              WT
# Name: 973, dtype: object
# row = cicid            3380572
# i94cit               266
# i94res               266
# i94port              LOS
# arr_yyyymmdd    20160418
# i94mode                1
# i94addr               FL
# dep_yyyymmdd        None
# i94bir                23
# i94visa                3
# i94count               1
# matflag             None
# biryear             1993
# gender                 M
# airline               UA
# fltno                180
# visatype              M1
# Name: 974, dtype: object
# row = cicid            5827765
# i94cit               582
# i94res               582
# i94port              PHO
# arr_yyyymmdd    20160430
# i94mode                1
# i94addr               OK
# dep_yyyymmdd        None
# i94bir                59
# i94visa                2
# i94count               1
# matflag             None
# biryear             1957
# gender                 F
# airline               Y4
# fltno              00902
# visatype              B2
# Name: 975, dtype: object
# row = cicid             499578
# i94cit               245
# i94res               245
# i94port              SFR
# arr_yyyymmdd    20160403
# i94mode                1
# i94addr               CA
# dep_yyyymmdd        None
# i94bir                29
# i94visa                3
# i94count               1
# matflag             None
# biryear             1987
# gender                 F
# airline               UA
# fltno              00889
# visatype              F1
# Name: 976, dtype: object
# row = cicid              54317
# i94cit               209
# i94res               209
# i94port              HHW
# arr_yyyymmdd    20160401
# i94mode                1
# i94addr               HI
# dep_yyyymmdd        None
# i94bir                28
# i94visa                2
# i94count               1
# matflag             None
# biryear             1988
# gender                 M
# airline               JL
# fltno              00782
# visatype              WT
# Name: 977, dtype: object
# row = cicid            5771544
# i94cit               514
# i94res               514
# i94port              BAL
# arr_yyyymmdd    20160430
# i94mode                1
# i94addr               MD
# dep_yyyymmdd        None
# i94bir                33
# i94visa                3
# i94count               1
# matflag             None
# biryear             1983
# gender                 M
# airline               WN
# fltno                907
# visatype              F1
# Name: 978, dtype: object
# row = cicid            4804280
# i94cit               582
# i94res               582
# i94port              DAL
# arr_yyyymmdd    20160425
# i94mode                1
# i94addr               CA
# dep_yyyymmdd        None
# i94bir                23
# i94visa                2
# i94count               1
# matflag             None
# biryear             1993
# gender                 F
# airline               Y4
# fltno              00892
# visatype              B2
# Name: 979, dtype: object
# row = cicid            5902022
# i94cit               112
# i94res               112
# i94port              HHW
# arr_yyyymmdd    20160415
# i94mode                9
# i94addr             None
# dep_yyyymmdd        None
# i94bir                55
# i94visa                2
# i94count               1
# matflag             None
# biryear             1961
# gender                 X
# airline             None
# fltno               None
# visatype              WT
# Name: 980, dtype: object
# row = cicid             751451
# i94cit               577
# i94res               577
# i94port              OTM
# arr_yyyymmdd    20160404
# i94mode                3
# i94addr               CA
# dep_yyyymmdd        None
# i94bir                25
# i94visa                2
# i94count               1
# matflag             None
# biryear             1991
# gender                 M
# airline             None
# fltno               LAND
# visatype              B2
# Name: 981, dtype: object
# row = cicid            6034994
# i94cit               252
# i94res               209
# i94port              AGA
# arr_yyyymmdd    20160429
# i94mode                1
# i94addr               GU
# dep_yyyymmdd        None
# i94bir                23
# i94visa                2
# i94count               1
# matflag             None
# biryear             1993
# gender                 M
# airline               UA
# fltno              00827
# visatype             GMT
# Name: 982, dtype: object
# row = cicid            2814946
# i94cit               582
# i94res               582
# i94port              ONT
# arr_yyyymmdd    20160415
# i94mode                1
# i94addr               CA
# dep_yyyymmdd        None
# i94bir                51
# i94visa                2
# i94count               1
# matflag             None
# biryear             1965
# gender                 F
# airline               AM
# fltno              00780
# visatype              B2
# Name: 983, dtype: object
# row = cicid            5020169
# i94cit               113
# i94res               113
# i94port              NYC
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               NY
# dep_yyyymmdd        None
# i94bir                33
# i94visa                2
# i94count               1
# matflag             None
# biryear             1983
# gender                 M
# airline               TK
# fltno              00003
# visatype              WT
# Name: 984, dtype: object
# row = cicid            2892590
# i94cit               123
# i94res               123
# i94port              WAS
# arr_yyyymmdd    20160416
# i94mode                1
# i94addr               MD
# dep_yyyymmdd        None
# i94bir                61
# i94visa                1
# i94count               1
# matflag             None
# biryear             1955
# gender                 F
# airline               SK
# fltno              00925
# visatype              WB
# Name: 985, dtype: object
# row = cicid            3434626
# i94cit               582
# i94res               582
# i94port              CHI
# arr_yyyymmdd    20160418
# i94mode                1
# i94addr               IL
# dep_yyyymmdd        None
# i94bir                70
# i94visa                2
# i94count               1
# matflag             None
# biryear             1946
# gender                 M
# airline               Y4
# fltno              00946
# visatype              B2
# Name: 986, dtype: object
# row = cicid            1044320
# i94cit               258
# i94res               258
# i94port              NYC
# arr_yyyymmdd    20160406
# i94mode                1
# i94addr               MI
# dep_yyyymmdd        None
# i94bir                29
# i94visa                2
# i94count               1
# matflag             None
# biryear             1987
# gender                 F
# airline               QR
# fltno              00701
# visatype              B2
# Name: 987, dtype: object
# row = cicid            4106787
# i94cit               258
# i94res               258
# i94port              WAS
# arr_yyyymmdd    20160422
# i94mode                1
# i94addr               MA
# dep_yyyymmdd        None
# i94bir                26
# i94visa                3
# i94count               1
# matflag             None
# biryear             1990
# gender                 F
# airline               QR
# fltno              00707
# visatype              F2
# Name: 988, dtype: object
# row = cicid            4456287
# i94cit               687
# i94res               687
# i94port              MIA
# arr_yyyymmdd    20160423
# i94mode                1
# i94addr               FL
# dep_yyyymmdd        None
# i94bir                32
# i94visa                2
# i94count               1
# matflag             None
# biryear             1984
# gender                 M
# airline               AR
# fltno              01302
# visatype              B2
# Name: 989, dtype: object
# row = cicid             561992
# i94cit               582
# i94res               582
# i94port              CHI
# arr_yyyymmdd    20160403
# i94mode                1
# i94addr               IL
# dep_yyyymmdd        None
# i94bir                28
# i94visa                2
# i94count               1
# matflag             None
# biryear             1988
# gender                 M
# airline               Y4
# fltno                940
# visatype              B2
# Name: 990, dtype: object
# row = cicid            5069811
# i94cit               213
# i94res               213
# i94port              BOS
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               MA
# dep_yyyymmdd        None
# i94bir                70
# i94visa                2
# i94count               1
# matflag             None
# biryear             1946
# gender                 F
# airline               QR
# fltno              00743
# visatype              B2
# Name: 991, dtype: object
# row = cicid            5928244
# i94cit               438
# i94res               438
# i94port              HHW
# arr_yyyymmdd    20160423
# i94mode                2
# i94addr             None
# dep_yyyymmdd        None
# i94bir                70
# i94visa                2
# i94count               1
# matflag                M
# biryear             1946
# gender                 M
# airline             None
# fltno               None
# visatype              WT
# Name: 992, dtype: object
# row = cicid             888522
# i94cit               512
# i94res               512
# i94port              FTL
# arr_yyyymmdd    20160405
# i94mode                1
# i94addr               IN
# dep_yyyymmdd        None
# i94bir                61
# i94visa                2
# i94count               1
# matflag             None
# biryear             1955
# gender              None
# airline               B6
# fltno              02316
# visatype              B2
# Name: 993, dtype: object
# row = cicid            3360046
# i94cit               213
# i94res               213
# i94port              NYC
# arr_yyyymmdd    20160418
# i94mode                1
# i94addr               CT
# dep_yyyymmdd        None
# i94bir                66
# i94visa                2
# i94count               1
# matflag             None
# biryear             1950
# gender                 F
# airline               AI
# fltno              00101
# visatype              B2
# Name: 994, dtype: object
# row = cicid            5928085
# i94cit               438
# i94res               438
# i94port              HHW
# arr_yyyymmdd    20160423
# i94mode                2
# i94addr             None
# dep_yyyymmdd        None
# i94bir                74
# i94visa                2
# i94count               1
# matflag                M
# biryear             1942
# gender                 M
# airline             None
# fltno               None
# visatype              WT
# Name: 995, dtype: object
# row = cicid            3484147
# i94cit               103
# i94res               103
# i94port              MIA
# arr_yyyymmdd    20160419
# i94mode                1
# i94addr               FL
# dep_yyyymmdd        None
# i94bir                63
# i94visa                2
# i94count               1
# matflag             None
# biryear             1953
# gender                 F
# airline               AB
# fltno              07000
# visatype              WT
# Name: 996, dtype: object
# row = cicid            3535501
# i94cit               245
# i94res               245
# i94port              NEW
# arr_yyyymmdd    20160419
# i94mode                1
# i94addr               PA
# dep_yyyymmdd        None
# i94bir                56
# i94visa                2
# i94count               1
# matflag             None
# biryear             1960
# gender                 F
# airline               UA
# fltno              00087
# visatype              B2
# Name: 997, dtype: object
# row = cicid            1032729
# i94cit               213
# i94res               213
# i94port              PHI
# arr_yyyymmdd    20160406
# i94mode                1
# i94addr               NJ
# dep_yyyymmdd        None
# i94bir                70
# i94visa                2
# i94count               1
# matflag             None
# biryear             1946
# gender                 M
# airline               BA
# fltno              00069
# visatype              B2
# Name: 998, dtype: object
# row = cicid            5018908
# i94cit               111
# i94res               111
# i94port              MON
# arr_yyyymmdd    20160427
# i94mode                1
# i94addr               FL
# dep_yyyymmdd        None
# i94bir                60
# i94visa                2
# i94count               1
# matflag             None
# biryear             1956
# gender                 M
# airline               RV
# fltno              01606
# visatype              WT
# Name: 999, dtype: object

# %%
conn.commit()
conn.close()
